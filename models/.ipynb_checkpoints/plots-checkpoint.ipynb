# %%
import pandas as pd

df = pd.read_csv('../datasets/data_4000v/env_vital_signals.txt', sep=',')
df.head()
# Out:
#    id       pSis       pDia       qPA       pulse       freq    gravity  label
# 0   0  14.968414  14.869604  8.652291  122.324349   5.623564  25.868691      2
# 1   1  16.397160  12.220855  8.733333  135.824333  12.787053  35.650207      2
# 2   2  21.624540  13.586879  8.733333   97.100546   1.553286  37.109058      2
# 3   3  16.458690   1.904802 -4.333333    6.943670   8.233419  27.122605      2
# 4   4  18.521669  13.700638  8.733333   22.887924   0.738972  13.222719      1

# %%
df.boxplot(by='label', column=['freq'])
# Out:
# <Axes: title={'center': 'freq'}, xlabel='label'>

# %%
df.boxplot(by='label', column=['pulse'])
# Out:
# <Axes: title={'center': 'pulse'}, xlabel='label'>

# %%
df.boxplot(by='label', column=['qPA'])
# Out:
# <Axes: title={'center': 'qPA'}, xlabel='label'>

# %%
df.boxplot(by='label', column=['pSis'])
# Out:
# <Axes: title={'center': 'pSis'}, xlabel='label'>

# %%
df.boxplot(by='label', column=['pDia'])
# Out:
# <Axes: title={'center': 'pDia'}, xlabel='label'>
